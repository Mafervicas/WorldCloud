# %% [markdown]
# # Código para Actividad 2
# Utilizando python para generar worldclouds y cumplir con la actividad de manera creativa

# %%
#Instalamos la libreria
#!pip install newspaper3k
#!pip install wordcloud
#!pip install matplotlib
#!pip install numpy

# %%
#Importamos la librería
from newspaper import Article

# %%
#Guardamos todo lo de la pagina en una variable
pagina = Article('https://fococonsultores.es/las-cualidades-de-un-buen-jefe/')
pagina.download()
pagina.parse()

# %%
#Nos quedamos con el texto
pagina.text
# Out:
# 'Un buen líder posee la visión integral de cómo los miembros de su equipo pueden aportar para alcanzar los objetivos que se han trazado.\n\nTiene la posibilidad de ofrecer perspectiva ante las dificultades que se presenten y apoyar a cada integrante para encontrar aquellas herramientas o vías para afrontarlas.\n\nDe esta manera garantiza que se mantenga el rumbo fijado sin perder el norte.\n\nEs cosa del pasado que los líderes tuvieran en las empresas el estereotipado rol de fiscalizar a los trabajadores, vigilar su trabajo y presionarles para alcanzar las metas.\n\nEn la actualidad existe un nuevo modelo de liderazgo más enfocado en ofrecer acompañamiento y en apoyar a los empleados y equipos de trabajo.\n\nLas organizaciones se han dado cuenta de cuánta verdad hay en el refrán:\n\nMás se consigue con miel que con hiel\n\nDe la misma forma han podido corroborar el importante papel que tienen los líderes en un mundo laboral cada vez más complejo y competitivo en el que tener una buen
# ...

# %%
#Importamos librerías
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS

# %%
imagen = WordCloud()
imagen.generate(pagina.text)
plt.imshow(imagen, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
#Importamos librería
from PIL import Image
import numpy as np

# %%
mask = np.array(Image.open('C:\\Users\\mafer\\Documents\\Programas.Maf\\PythonScripts\\DataAnalitics\\Maf/trofeo.png'))
wc = WordCloud(stopwords=STOPWORDS,
               mask=mask, background_color="white",min_word_length=4 ,contour_width=3, contour_color='green',
               max_words=2500, max_font_size=256,
               random_state=42)
wc.generate(pagina.text)
plt.figure( figsize=(25,20) )
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # Mal Jefe

# %%
pagina2 = Article('https://www.significados.com/defectos-de-una-persona/')
pagina2.download()
pagina2.parse()

# %%
pagina2.text
# Out:
# 'Los defectos son las actitudes o comportamientos que resultan desagradables, incómodos, y que de una u otra manera afectan a quienes nos rodean e incluso a nosotros mismos.\n\nPor tanto, los defectos componen un conjunto de características indeseables que se deben evitar y corregir a fin de consolidar mejores relaciones sociales y ser mejores personas. Así se reducen las injusticias, se suman amistades, se puede llegar a diversos acuerdos y vivir en armonía con quienes nos rodean.\n\nAhora bien, ¿sabes cuáles defectos puedes reconocer en ti? y, ¿cuáles son los defectos que más te perturban de los demás?\n\n1. Mal humor\n\nHay personas que se caracterizan por estar constantemente de mal humor por diversas razones, bien sean familiares, laborales, personales, entre muchas otras. Sin embargo, a nadie le gusta estar con este tipo de personas porque no tienen sentido del humor y porque su pesado estado de ánimo se contagia en los demás.\n\n2. Mentira\n\nDecir mentiras es uno de los defec
# ...

# %%
mask = np.array(Image.open('C:\\Users\\mafer\\Documents\\Programas.Maf\\PythonScripts\\DataAnalitics\\Maf/dislike.jpg'))
wc2 = WordCloud(stopwords=STOPWORDS,
               mask=mask, background_color="white",
               max_words=1000, max_font_size=100,min_word_length=4,
               random_state=42)
wc2.generate(pagina2.text)
plt.figure( figsize=(15,10) )
plt.imshow(wc2, interpolation="bilinear")
plt.axis('off')
plt.show()
